# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd

train = pd.read_csv('/content/drive/MyDrive/test2/train.csv')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 1. 누락됐었던 예매자 :
# #   1) 892 / 생존 / 1등석 / Advocate Mr. Will / female / 42 / 1 / 0 / C5F 34405 / 34.01 / A3 / S

# %%
train.loc[891]= [892 , 1 , 1 , 'Advocate Mr. Will' , 'female' , 42 , 1 , 0 , 'C5F 34405' , 34.01 , 'A3' , 'S']

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
# 891          892         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 2. 예매 변경 내역
# #   1) Allen, Miss. Elisabeth Walton씨가 열차출발 하루 전 2등석으로 예매변경을 했음
# #   2) Abbott, Mrs. Stanton (Rosa Hunt)씨는 열차출발 이틀 전 1등석으로 예매변경을 했음

# %%
train.loc[train['Name']=='Allen, Miss. Elisabeth Walton']
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 730          731         1       1  Allen, Miss. Elisabeth Walton  female
#
#       Age  SibSp  Parch Ticket      Fare Cabin Embarked
# 730  29.0      0      0  24160  211.3375    B5        S

# %%
train.iloc[730,2]=2

# %%
train.loc[train['Name']=='Allen, Miss. Elisabeth Walton']
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 730          731         1       2  Allen, Miss. Elisabeth Walton  female
#
#       Age  SibSp  Parch Ticket      Fare Cabin Embarked
# 730  29.0      0      0  24160  211.3375    B5        S

# %%
train.loc[train['Name']=='Abbott, Mrs. Stanton (Rosa Hunt)']
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 279          280         1       3  Abbott, Mrs. Stanton (Rosa Hunt)  female
#
#       Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# 279  35.0      1      1  C.A. 2673  20.25   NaN        S

# %%
train.iloc[279,2]=1

# %%
train.loc[train['Name']=='Abbott, Mrs. Stanton (Rosa Hunt)']
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 279          280         1       1  Abbott, Mrs. Stanton (Rosa Hunt)  female
#
#       Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# 279  35.0      1      1  C.A. 2673  20.25   NaN        S

# %%
train.loc[train['Name']=='Abbott, Mrs. Stanton (Rosa Hunt)','Pclass']
# Out:
# 279    1
# Name: Pclass, dtype: int64

# %% [markdown]
# # 3. 조사 결과 실제와 달랐던 내역
# #   1) Andrews, Miss. Kornelia Theodosia씨는 추후 조사결과 사망한 것으로 판정됨

# %%
train.loc[train['Name']=='Andrews, Miss. Kornelia Theodosia','Survived']
# Out:
# 275    1
# Name: Survived, dtype: int64

# %%
train.loc[train['Name']=='Andrews, Miss. Kornelia Theodosia','Survived']=0

# %%
train.loc[train['Name']=='Andrews, Miss. Kornelia Theodosia','Survived']
# Out:
# 275    0
# Name: Survived, dtype: int64

# %% [markdown]
# # 그리고 퇴근 무렵, 그의 상사인 Kelly Kim이 지금까지 작업한 내역을 토대로,
# #  * 1등석을 예매한 고객들 중, 열차사고에서 생존한 고객들을 알파벳순으로 오름차순으로 정렬하여 상위 20명의 고객의 명단을 뽑아서 본인에게 달라고 요청하였다.

# %%
train.loc[ (train['Pclass']==1) & (train['Survived']==1) ]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 23            24         1       1
# 31            32         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
# 891          892         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.loc[ (train['Pclass']==1) & (train['Survived']==1) ].sort_values(by= 'Name')
# Out:
#      PassengerId  Survived  Pclass  \
# 279          280         1       1
# 891          892         1       1
# 305          306         1       1
# 460          461         1       1
# 571          572         1       1
# ..           ...       ...     ...
# 366          367         1       1
# 318          319         1       1
# 856          857         1       1
# 55            56         1       1
# 325          326         1       1
#
#                                                  Name     Sex    Age  SibSp  \
# 279                  Abbott, Mrs. Stanton (Rosa Hunt)  female  35.00      1
# 891                                 Advocate Mr. Will  female  42.00      1
# 305                    Allison, Master. Hudson Trevor    male   0.92      1
# 460                               Anderson, Mr. Harry    male  48.00      0
# 571     Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.00      2
# ..                                                ...     ...    ...    ...
# ...

# %%
train.loc[ (train['Pclass']==1) & (train['Survived']==1) ].sort_values(by= 'Name').head()
# Out:
#      PassengerId  Survived  Pclass  \
# 279          280         1       1
# 891          892         1       1
# 305          306         1       1
# 460          461         1       1
# 571          572         1       1
#
#                                               Name     Sex    Age  SibSp  \
# 279               Abbott, Mrs. Stanton (Rosa Hunt)  female  35.00      1
# 891                              Advocate Mr. Will  female  42.00      1
# 305                 Allison, Master. Hudson Trevor    male   0.92      1
# 460                            Anderson, Mr. Harry    male  48.00      0
# 571  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.00      2
#
#      Parch     Ticket      Fare    Cabin Embarked
# 279      1  C.A. 2673   20.2500      NaN        S
# 891      0  C5F 34405   34.0100       A3        S
# 305      2     113781  151.5500  C22 C26        S
# 460      0      19952   26.5500      E12        S
# 571      0      11769   51.4792     C101        S
